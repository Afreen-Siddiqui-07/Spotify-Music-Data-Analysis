# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/Asus/Downloads/archive (1)/spotify_tracks.csv")

# %%
df.head()
# Out:
#                  track_id                                  track_name  \
# 0  2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1  4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2  59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3  5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4  1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
#
#                                          artist_name  year  popularity  \
# 0                                Anirudh Ravichander  2024          59
# 1  Anirudh Ravichander, Pravin Mani, Vaishali Sri...  2024          47
# 2           Anirudh Ravichander, Anivee, Alvin Bruno  2024          35
# 3  Anirudh Ravichander, Bharath Sankar, Kabilan, ...  2024          24
# 4  Anirudh Ravichander, Benny Dayal, Leon James, ...  2024          22
#
#                                          artwork_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273ce9c65...
# ...

# %%
pd.isnull(df).sum()
# Out:
# track_id            0
# track_name          0
# artist_name         0
# year                0
# popularity          0
# artwork_url         0
# album_name          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# track_url           0
# language            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62317 entries, 0 to 62316
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          62317 non-null  object
#  1   track_name        62317 non-null  object
#  2   artist_name       62317 non-null  object
#  3   year              62317 non-null  int64
#  4   popularity        62317 non-null  int64
#  5   artwork_url       62317 non-null  object
#  6   album_name        62317 non-null  object
#  7   acousticness      62317 non-null  float64
#  8   danceability      62317 non-null  float64
#  9   duration_ms       62317 non-null  float64
#  10  energy            62317 non-null  float64
#  11  instrumentalness  62317 non-null  float64
#  12  key               62317 non-null  float64
#  13  liveness          62317 non-null  float64
#  14  loudness          62317 non-null  float64
#  15  mode              62317 non-null  float64
# ...

# %%
sorted_df = df.sort_values("popularity",ascending = True).head(10)
sorted_df
# Out:
#                      track_id                     track_name  \
# 38054  0lV9vfSUbv242tfvr4UJmH           Locked Out of Heaven
# 49621  4mLTQTnjASz2cyNrdSGajG                    Puthusa Oru
# 40237  5T6RbU0c8u2BAiiiGBCOPt            Thambala Sundariyae
# 40324  4QRWPevIlr920AjgLRBiwD      Nandavanam Poothirikkudhu
# 40325  5Gtk81L3vj3VebhwUq3KkK             Raathiri Poothathu
# 61335  6fB5tQyTx3joWUUchHJs4K  Chapter 201 - Nowhere to Hide
# 40326  3Qt2ewtK9B8Fy0i8pqPELA                      Sollatuma
# 61336  2XMrgT7uHF5HGyP5MU0n3l   Chapter 26 - Nowhere to Hide
# 61337  3Xee7EjvEmdHGklr8JQqsK  Chapter 134 - Nowhere to Hide
# 61338  1S99KEcWhxihxejmwZiWE0  Chapter 154 - Nowhere to Hide
#
#                                              artist_name  year  popularity  \
# 38054                                         Bruno Mars  2024           0
# 49621  Ilaiyaraaja, Vaali, K. S. Chithra, Malaysia Va...  1993           0
# ...

# %%
df.describe()
# Out:
#                year    popularity  acousticness  danceability   duration_ms  \
# count  62317.000000  62317.000000  62317.000000  62317.000000  6.231700e+04
# mean    2014.425935     15.358361      0.362292      0.596807  2.425270e+05
# std        9.645113     18.626908      0.314609      0.186209  1.129999e+05
# min     1971.000000      0.000000     -1.000000     -1.000000  5.000000e+03
# 25%     2011.000000      0.000000      0.067100      0.497000  1.921600e+05
# 50%     2017.000000      7.000000      0.286000      0.631000  2.362670e+05
# 75%     2022.000000     26.000000      0.632000      0.730000  2.862400e+05
# max     2024.000000     93.000000      0.996000      0.986000  4.581483e+06
#
#              energy  instrumentalness           key      liveness  \
# count  62317.000000      62317.000000  62317.000000  62317.000000
# mean       0.602496          0.146215      5.101658      0.194143
# std        0.246144          0.307804      3.553469      0.172030
# ...

# %%
most_pop = df.query("popularity>80" ,inplace = False).sort_values("popularity",ascending = False)
most_pop[:10]
# Out:
#                      track_id  \
# 49479  0OA00aPt3BV10qeMIs3meW
# 26432  0VjIjW4GlUZAMYd2vXMi3b
# 26580  7MXVkk9YMctZqd1Srtv4MB
# 54962  62bOmKYxYg7dhrC6gH9vFn
# 23702  0V3wPSX9ygBnCm8psDIegu
# 24273  4R2kfaDFhslZEMJqAFNpdd
# 23514  1Iq8oo9XkmmvCQiGOfORiz
# 31241  2O4Bb2WCkjlTPO827OnBMI
# 22876  2tpWsVSb9UEmDRxAl1zhX1
# 24274  3hUxzQpSfdDqwM3ZTFQY0K
#
#                                               track_name  \
# 49479                                          Big Dawgs
# 26432                                    Blinding Lights
# 26580                                            Starboy
# 54962  Bye Bye Bye - From Deadpool and Wolverine Soun...
# 23702                                          Anti-Hero
# 24273                                           cardigan
# 23514  Is It Over Now? (Taylor's Version) (From The V...
# 31241                                               EASY
# 22876                                     Counting Stars
# ...

# %%
df[["artist_name"]].loc[18]
# Out:
# artist_name    Anirudh Ravichander, Dhee, Santhosh Narayanan,...
# Name: 18, dtype: object

# %%
df.head()
# Out:
#                  track_id                                  track_name  \
# 0  2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1  4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2  59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3  5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4  1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
#
#                                          artist_name  year  popularity  \
# 0                                Anirudh Ravichander  2024          59
# 1  Anirudh Ravichander, Pravin Mani, Vaishali Sri...  2024          47
# 2           Anirudh Ravichander, Anivee, Alvin Bruno  2024          35
# 3  Anirudh Ravichander, Bharath Sankar, Kabilan, ...  2024          24
# 4  Anirudh Ravichander, Benny Dayal, Leon James, ...  2024          22
#
#                                          artwork_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273ce9c65...
# ...

# %%
df['duration_min'] = df['duration_ms'] / 60000
df['duration_min'] = df['duration_min'].round(2)
df.drop("duration_ms",inplace = True,axis=1)

# %%
df.head()
# Out:
#                  track_id                                  track_name  \
# 0  2r0ROhr7pRN4MXDMT1fEmd                  Leo Das Entry (From "Leo")
# 1  4I38e6Dg52a2o2a8i5Q5PW                                AAO KILLELLE
# 2  59NoiRhnom3lTeRFaBzOev      Mayakiriye Sirikiriye - Orchestral EDM
# 3  5uUqRQd385pvLxC8JX3tXn    Scene Ah Scene Ah - Experimental EDM Mix
# 4  1KaBRg2xgNeCljmyxBH1mo  Gundellonaa X I Am A Disco Dancer - Mashup
#
#                                          artist_name  year  popularity  \
# 0                                Anirudh Ravichander  2024          59
# 1  Anirudh Ravichander, Pravin Mani, Vaishali Sri...  2024          47
# 2           Anirudh Ravichander, Anivee, Alvin Bruno  2024          35
# 3  Anirudh Ravichander, Bharath Sankar, Kabilan, ...  2024          24
# 4  Anirudh Ravichander, Benny Dayal, Leon James, ...  2024          22
#
#                                          artwork_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273ce9c65...
# ...

# %%
filtered_data = df.drop(columns=['key', 'mode'])
numeric_col = filtered_data.select_dtypes(include=['float64', 'int64']).columns

correlation_matrix = filtered_data[numeric_col].corr(method='pearson')
plt.figure(figsize=(16, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title("Correlation Heatmap Matrix ", fontsize=16)
plt.show()

# %%
popularity_trend = df.groupby('year')['popularity'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=popularity_trend, x='year', y='popularity', marker='o', color="orange")
plt.title("Average Track Popularity Over the Years", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("popularity", fontsize=12)
plt.show()

# %%
sns.set_palette("bright")
sns.set_style("whitegrid")


plt.figure(figsize=(10, 6))
sns.histplot(df['popularity'], bins=30, kde=True, color="teal")
plt.title("Distribution of Track Popularity", fontsize=16)
plt.xlabel("Popularity", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df, x='energy', y='danceability', 
    alpha=0.6, color="purple"
)
plt.title("Energy vs. Danceability", fontsize=16)
plt.xlabel("Energy", fontsize=12)
plt.ylabel("Danceability", fontsize=12)
plt.show()

# %%
track_per_year = df['year'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
sns.lineplot(x=track_per_year.index, y=track_per_year.values, marker='o', color='green')
plt.title("No of Tracks Released Per Year", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("No. of Tracks", fontsize=12)
plt.show()

# %%
top_10_popular = most_pop.head(10)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_popular, x='track_name', y='popularity', palette="viridis")


plt.title("Top 10 Most Popular Tracks", fontsize=16)
plt.xlabel("Track Name", fontsize=12)
plt.ylabel("Popularity", fontsize=12)


plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_5964\53315934.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10_popular, x='track_name', y='popularity', palette="viridis")
